# %% [markdown]
# <a href="https://colab.research.google.com/github/shivakumardodda/shivakumardodda/blob/data-science/EDA%201_assigment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#  **DODDA SHIVA KUMAR**

# %% [markdown]
# **1.Data cleaning and prepartion**

# %%
#import basic labraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
#reading the data set
df=pd.read_csv("Cardiotocographic.csv")
df
# Out:
#               LB        AC        FM        UC        DL   DS   DP  ASTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0
# ...          ...       ...       ...       ...       ...  ...  ...   ...
# 2121  140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.0  79.0
# 2122  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0
# 2123  140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0
# 2124  140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0
# 2125  142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0
#
#       MSTV       ALTV  MLTV  Width  Tendency       NSP
# ...

# %%
#Quick overview of the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2126 entries, 0 to 2125
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   LB        2105 non-null   float64
#  1   AC        2106 non-null   float64
#  2   FM        2126 non-null   float64
#  3   UC        2126 non-null   float64
#  4   DL        2126 non-null   float64
#  5   DS        2105 non-null   float64
#  6   DP        2105 non-null   float64
#  7   ASTV      2126 non-null   float64
#  8   MSTV      2126 non-null   float64
#  9   ALTV      2126 non-null   float64
#  10  MLTV      2105 non-null   float64
#  11  Width     2105 non-null   float64
#  12  Tendency  2105 non-null   float64
#  13  NSP       2105 non-null   float64
# dtypes: float64(14)
# memory usage: 232.7 KB

# %%
df.describe()
# Out:
#                 LB           AC           FM           UC           DL  \
# count  2105.000000  2106.000000  2126.000000  2126.000000  2126.000000
# mean    133.343598     0.003219     0.009894     0.004391     0.001895
# std      11.270154     0.004391     0.067540     0.003340     0.003343
# min      51.842487    -0.019284    -0.480634    -0.014925    -0.015393
# 25%     126.000000     0.000000     0.000000     0.001851     0.000000
# 50%     133.000000     0.001634     0.000000     0.004484     0.000000
# 75%     140.000000     0.005650     0.002567     0.006536     0.003289
# max     214.000000     0.038567     0.961268     0.030002     0.030769
#
#                 DS           DP         ASTV         MSTV         ALTV  \
# count  2105.000000  2105.000000  2126.000000  2126.000000  2126.000000
# mean      0.000003     0.000175    46.995984     1.364378    10.285964
# std       0.000142     0.000840    18.813973     1.173632    21.205041
# ...

# %%
#Repersent the data tyeps in dataset
df.dtypes
# Out:
# LB          float64
# AC          float64
# FM          float64
# UC          float64
# DL          float64
# DS          float64
# DP          float64
# ASTV        float64
# MSTV        float64
# ALTV        float64
# MLTV        float64
# Width       float64
# Tendency    float64
# NSP         float64
# dtype: object

# %%
# To know the shape of the dataset
df.shape
# Out:
# (2126, 14)

# %%
#To find the sum of null values
df.isnull().sum()
# Out:
# LB          21
# AC          20
# FM           0
# UC           0
# DL           0
# DS          21
# DP          21
# ASTV         0
# MSTV         0
# ALTV         0
# MLTV        21
# Width       21
# Tendency    21
# NSP         21
# dtype: int64

# %%
#copying the original data into other dataset
df1=df.copy()
df1
# Out:
#               LB        AC        FM        UC        DL   DS   DP  ASTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0
# ...          ...       ...       ...       ...       ...  ...  ...   ...
# 2121  140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.0  79.0
# 2122  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0
# 2123  140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0
# 2124  140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0
# 2125  142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0
#
#       MSTV       ALTV  MLTV  Width  Tendency       NSP
# ...

# %%
#It will display the dulipcate data in data set
df[df.duplicated()]
# Out:
#          LB        AC   FM        UC   DL   DS   DP  ASTV  MSTV  ALTV  MLTV  \
# 1115  122.0  0.000000  0.0  0.000000  0.0  0.0  0.0  19.0   1.9   0.0  15.1
# 1458  148.0  0.004717  0.0  0.002358  0.0  0.0  0.0  40.0   0.9   0.0  10.6
#
#       Width  Tendency  NSP
# 1115   39.0       0.0  1.0
# 1458   35.0       0.0  1.0

# %%
#It will drop the duplicate data in given dataset
df1=df1.drop_duplicates()

# %%
df1.shape
# Out:
# (2124, 14)

# %%
df1.isnull().sum()
# Out:
# LB          21
# AC          20
# FM           0
# UC           0
# DL           0
# DS          21
# DP          21
# ASTV         0
# MSTV         0
# ALTV         0
# MLTV        21
# Width       21
# Tendency    21
# NSP         21
# dtype: int64

# %% [markdown]
# **Imputation Technique**

# %%
#Now we are going to perform imputation techniques to treat null values in given dataset.
#mean,median are performed on numerical columns.
#mode is performed on catgorical columns.

mean=df1['AC'].mean()

# %%
df1['AC']=df1['AC'].fillna(mean)
# Out:
# <ipython-input-96-82248fa53508>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['AC']=df1['AC'].fillna(mean)

# %%
df1['AC'].isnull().sum()
# Out:
# 0

# %%
df1['LB']=df1['LB'].fillna(mean)
# Out:
# <ipython-input-98-66155cff32cb>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['LB']=df1['LB'].fillna(mean)

# %%
df1['DS']=df1['DS'].fillna(mean)
# Out:
# <ipython-input-99-7b92755fcefa>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['DS']=df1['DS'].fillna(mean)

# %%
df1['DP']=df1['DP'].fillna(mean)
# Out:
# <ipython-input-100-44274e7b5d01>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['DP']=df1['DP'].fillna(mean)

# %%
df1['MLTV']=df1['MLTV'].fillna(mean)
# Out:
# <ipython-input-101-2cf82cb08f48>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['MLTV']=df1['MLTV'].fillna(mean)

# %%
df1['Width']=df1['Width'].fillna(mean)
# Out:
# <ipython-input-102-268794679b5c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Width']=df1['Width'].fillna(mean)

# %%
df1['Tendency']=df1['Tendency'].fillna(mean)
# Out:
# <ipython-input-103-ac6ff0fc06d9>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Tendency']=df1['Tendency'].fillna(mean)

# %%
df1['NSP']=df1['NSP'].fillna(mean)
# Out:
# <ipython-input-104-a50434a8ee26>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['NSP']=df1['NSP'].fillna(mean)

# %%
#no null values present in dataset after performing imputation technique by using mean value
#we did not use mode because we didnot perform any imputation on catgorical columns
df1.isnull().sum()
# Out:
# LB          0
# AC          0
# FM          0
# UC          0
# DL          0
# DS          0
# DP          0
# ASTV        0
# MSTV        0
# ALTV        0
# MLTV        0
# Width       0
# Tendency    0
# NSP         0
# dtype: int64

# %%
#correlation between the columns in given dataset.
df1.corr()
# Out:
#                 LB        AC        FM        UC        DL        DS  \
# LB        1.000000 -0.070415  0.019974 -0.114855 -0.088979 -0.698291
# AC       -0.070415  1.000000  0.009406  0.071552 -0.093330  0.021796
# FM        0.019974  0.009406  1.000000 -0.053386  0.009641  0.002745
# UC       -0.114855  0.071552 -0.053386  1.000000  0.189737  0.005533
# DL       -0.088979 -0.093330  0.009641  0.189737  1.000000  0.032083
# DS       -0.698291  0.021796  0.002745  0.005533  0.032083  1.000000
# DP       -0.287452 -0.065345  0.110598  0.069274  0.139402  0.311683
# ASTV      0.156933 -0.231058 -0.032838 -0.182379 -0.069907  0.002865
# MSTV     -0.131511  0.133903  0.017061  0.189685  0.410216  0.032829
# ALTV      0.160810 -0.271204 -0.012005 -0.227881 -0.187275 -0.031055
# MLTV      0.078164 -0.108128 -0.005045 -0.049444 -0.164997 -0.082458
# Width     0.047090  0.225457  0.097504  0.103690  0.401609 -0.130978
# Tendency  0.190096  0.030004 -0.017894 -0.067311 -0.024176 -0.050317
# ...

# %%
#standardization the data
from sklearn.preprocessing import StandardScaler

# Fit and transform the numerical columns
scaler = StandardScaler()
df1[df1.columns] = scaler.fit_transform(df1[df1.columns])
# Out:
# <ipython-input-107-45a51e8db155>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1[df1.columns] = scaler.fit_transform(df1[df1.columns])

# %% [markdown]
# **3.Statistical Summary**

# %%
#Statistical Summary of all columns
for column in df1.columns:
    print(f"Statistical Summary for {column}:")
    print(f'mean: {df1[column].mean()}')
    print(f'meadian: {df1[column].median()}')
    print(f'standard deviation: {df[column].std()}')
    print(f'variance: {df[column].var()}')
    print(f'skewness: {df[column].skew()}')
    def IQR(df1, column):
      Q1 = df1[column].quantile(0.25)
      Q3 = df1[column].quantile(0.75)
      IQR = Q3 - Q1
      return IQR,Q1,Q3
    print("IQR , Q1 , Q3 :", IQR(df1, column))
    print()
# Out:
# Statistical Summary for LB:
# mean: 8.630886338328901e-16
# meadian: 0.05639443608627817
# standard deviation: 11.270154059450766
# variance: 127.01637252375458
# skewness: 0.3207470577305014
# IQR , Q1 , Q3 : (0.8086893187049307, -0.34795022326618713, 0.4607390954387435)
#
# Statistical Summary for AC:
# mean: 1.0704975303353675e-16
# meadian: -0.3550556915749713
# standard deviation: 0.004390772421026121
# variance: 1.927888245324359e-05
# skewness: 2.0167874553200114
# IQR , Q1 , Q3 : (1.2841054009365596, -0.7367262277783877, 0.5473791731581719)
#
# Statistical Summary for FM:
# mean: 1.3381219129192093e-17
# meadian: -0.14660375318687094
# standard deviation: 0.06753967969018713
# variance: 0.004561608332653077
# skewness: 6.75306980198638
# IQR , Q1 , Q3 : (0.03801977319389051, -0.14660375318687094, -0.10858397999298043)
#
# Statistical Summary for UC:
# mean: 2.140995060670735e-16
# meadian: 0.027751303459575025
# standard deviation: 0.0033404622309868236
# ...

# %%
#Identifing the outliers using quartile
Q1 = df1.quantile(0.25)
Q3 = df1.quantile(0.75)
IQR = Q3 - Q1

# Identifying outliers
outliers = ((df1 < (Q1 - 1.5 * IQR)) | (df1 > (Q3 + 1.5 * IQR))).any(axis=1)

# Printing the row numbers of outliers
print("Outlier Row Numbers (IQR Method):")
print(df1.index[outliers].tolist())
# Out:
# Outlier Row Numbers (IQR Method):
# ...

# %% [markdown]
# **SUMMARY:**
#
# From the above stastical performance we found mean medain and std of the given dataset
#
# mean of all columns is "mean=1.29129
#
# Highest medain of the dataset is "Width=67.0"
#
# Highest std of the dataset is "width=43.292125"
# "AC,FM,UC,DL,DS,DP,MSTV,TENDENCY,NSP" Column do not have much Variance  so,drop those columns in visulizatin step.
#
# Even we got to know about the outliers in given dataset.

# %% [markdown]
# **3.Data Visulization**

# %%
#seaborn visualization library
import seaborn as sns

# %%
#we are droping this columns because there in no much variance in that columns
#And we dont even get much is full info from that columns
df1=df1.drop(['AC','FM','UC','DL','DS','DP','MSTV','Tendency','NSP'],axis=1)

# %%
for col in df1:
  #histogram
  fig,axes=plt.subplots(1,2,figsize=(8,5))
  sns.histplot(df1[col],bins=20,ax=axes[0],color='red',edgecolor='black')
  axes[0].set_xlabel(col)
  axes[0].set_ylabel('Frequency')
  axes[0].set_title(f'Histogram of {col}')

  #boxplot
  sns.boxplot(df1[col],ax=axes[1])
  axes[1].set_xlabel(col)
  axes[1].set_ylabel('Frequency')
  axes[1].set_title(f'Boxplot of {col}')

plt.show()

# %%
#we cannot visulize bar plot for numerical columns

# %%
#Correlation Heat map between pairs of variable in dataset.
import seaborn as sns
sns.heatmap(df1.corr())
# Out:
# <Axes: >

# %%
#Advanced visulization techniques for deeper insights.
#pairplots
import seaborn as sns
sns.pairplot(df1)

# %% [markdown]
# **4.	Pattern Recognition and Insights:**

# %%
import pandas as pd

# Assuming 'df1' is your DataFrame
correlation_matrix = df1.corr()

# Display the correlation matrix
print(correlation_matrix)
# Out:
#              LB      ASTV      ALTV      MLTV     Width
# LB     1.000000  0.156933  0.160810  0.078164  0.047090
# ASTV   0.156933  1.000000  0.357310 -0.217944 -0.204970
# ALTV   0.160810  0.357310  1.000000 -0.103363 -0.336816
# MLTV   0.078164 -0.217944 -0.103363  1.000000  0.074896
# Width  0.047090 -0.204970 -0.336816  0.074896  1.000000

# %% [markdown]
# **5.Conclusion from the dataset**

# %% [markdown]
# Discuss their potential implications.
#
# 1)Correlation indicates the extent to which two or more variables fluctuate together.
#
# 2)A positive correlation suggests that as one variable increases, the other tends to increase, while a negative correlation implies an inverse relationship.
#
# 3)High correlations might suggest redundancy in the data, or that one variable can predict another.
#
# 4)However, correlation does not equal causation; a strong correlation does not prove that one variable causes changes in the other.
#
# 5)Spurious correlations can arise due to confounding factors.

# %% [markdown]
# Data Cleaning:
#
# Duplicate Removal: Removing duplicate rows ensures that your analysis is not skewed by redundant data. This leads to more accurate results and better decision-making.
#
# Missing Value Imputation: Imputing missing values using the mean helps maintain the dataset's overall distribution. However, it's important to consider that using the mean might not always be the most appropriate method. Depending on the data and the context, other techniques like median or mode imputation might be more suitable.
#
# Outlier Detection and Treatment: Identifying and handling outliers is crucial for building robust models. Your analysis highlighted potential outliers in the 'AC' column. Further investigation and potentially treating these outliers (e.g., capping or removal) can prevent them from unduly influencing your results.
#
# Statistical Summary:
# Mean, Median, and Standard Deviation: These descriptive statistics provide insights into the central tendency, distribution, and variability of your data. Understanding these characteristics is essential for selecting appropriate statistical tests and models. For example, a high standard deviation in the 'Width' column indicates greater variability, which might require specific modeling considerations.
#
# Distribution Analysis: The histograms and box plots help visualize the distribution of your data. This can inform you about potential skewness, kurtosis, and the presence of distinct groups within the data. Understanding these distributions guides the choice of data transformations or specific modeling approaches.
# Visualization:
#
# Pair Plots and Heatmaps: Pair plots provide an overview of relationships between variables, helping you identify potential correlations. Heatmaps can highlight missing data patterns and correlations between variables. These visual insights can guide feature selection, model building, and the interpretation of results.
#
# Potential Impact on Further Analyses:
#
# Feature Engineering: Based on your findings, you might consider creating new features that capture interactions or relationships between existing variables.
#
# Model Selection: Your insights into data distribution and variable relationships will influence your choice of appropriate machine learning models.
#
# Model Evaluation: The quality of your data, including the handling of missing values and outliers, directly impacts the performance and reliability of your models.
#
# Decision-Making:
#
# Medical Diagnosis or Monitoring: The insights gained from your analysis can contribute to more informed decisions related to patient diagnosis, monitoring, or treatment strategies.
#
# Resource Allocation: The findings might inform decisions on how to allocate resources or prioritize patient care based on risk factors or identified patterns in the data.

# %% [markdown]
# Discuss how these findings could impact decision-making or further analyses
#
# 1)Define Target Variable:  Clearly specify the target variable to provide context for all analyses.
#
# 2)Feature Engineering:  Consider creating new features from the existing ones to capture more complex relationships.
#
# 3)Alternative Outlier Treatment:  Explore different outlier removal or imputation techniques.
#
# 4)Advanced Visualizations:  Use interactive plots or 3D visualizations for potentially deeper insight into the data structure.
#
# 5)Statistical Tests: Conduct statistical tests (e.g., ANOVA, t-tests) to formally assess the significance of observed differences or relationships between variables and the target variable.
#
# 6)Model Building: Develop predictive models to verify the insights obtained through EDA and to make predictions on new data.
