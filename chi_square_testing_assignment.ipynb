# %% [markdown]
# <a href="https://colab.research.google.com/github/shivakumardodda/shivakumardodda/blob/data-science/chi_square_testing_assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **DODDA SHIVA KUMAR**

# %% [markdown]
# # **CHI-SQUARE TEST**

# %% [markdown]
# **1. State the Hypothesis:**Hypothesis  is the statistical method which is used know the actual value by assumption regarding the population data by using sample data.
#
# Hypothesis is two types:
#
# H0=Null hypothesis.
#
# H1=Alternative hypothesis.
#
# Sample data:The data which is subset of the population data and its a peice of the data which is cost effective and time saving process

# %% [markdown]
# **2. Compute the Chi-Square Statistic:**

# %%
# prompt: Satisfaction	Smart Thermostat	Smart Light	Total
# Very Satisfied	50	70	120
# Satisfied	80	100	180
# Neutral	60	90	150
# Unsatisfied	30	50	80
# Very Unsatisfied	20	50	70
# Total	240	360	600 give in table formate

import pandas as pd
import numpy as np
from scipy.stats import chi2_contingency

data = {'Satisfaction': ['Very Satisfied', 'Satisfied', 'Neutral', 'Unsatisfied', 'Very Unsatisfied', 'Total'],
        'Smart Thermostat': [50, 80, 60, 30, 20, 240],
        'Smart Light': [70, 100, 90, 50, 50, 360],
        'Total': [120, 180, 150, 80, 70, 600]}

df = pd.DataFrame(data)
df
# Out:
#        Satisfaction  Smart Thermostat  Smart Light  Total
# 0    Very Satisfied                50           70    120
# 1         Satisfied                80          100    180
# 2           Neutral                60           90    150
# 3       Unsatisfied                30           50     80
# 4  Very Unsatisfied                20           50     70
# 5             Total               240          360    600

# %%
# Make sure the import statement is in the same code block:
import pandas as pd
import numpy as np
from scipy.stats import chi2_contingency # Import chi2_contingency here

# ... (rest of your code) ...

chi_square = chi2_contingency(df.iloc[0:5, 1:3])
chi_square
# Out:
# Chi2ContingencyResult(statistic=5.638227513227513, pvalue=0.22784371130697179, dof=4, expected_freq=array([[ 48.,  72.],
#        [ 72., 108.],
#        [ 60.,  90.],
#        [ 32.,  48.],
#        [ 28.,  42.]]))

# %% [markdown]
# Chi-Square(x**2)=Σ(observed frequency(O)-expected frequency(E))/expected frequency(E)
#
# Expected frequency(E)=Total no.of observation in row*Total no.of observations in column /Total no.of observations
#
# df(degrees of feedom)=(no.of rows-1)*(no.of columns-1)
#
# By using above forumal we will find the chi-square statistical value.
#
# convert the tabled values into requied values in formula.
#
# x^2=0.833+0.888+0+0.125+3.2+0.055+0.592+0+0.833+18.666=25.192
#
# Chi2-stastistical=25.192

# %% [markdown]
# **3.Determine the Critical Value:**
# Using the significance level (alpha) of 0.05 and the degrees of freedom (which is the number of categories minus 1)

# %%
import pandas as pd
import numpy as np
from scipy.stats import chi2_contingency
from scipy.stats import chi2

chi_square_result = chi2_contingency(df.iloc[0:5, 1:3])
degrees_of_freedom = chi_square_result[2]
alpha = 0.05

# Calculate the critical value
critical_value = chi2.ppf(1 - alpha, degrees_of_freedom)

print(f"Degrees of Freedom: {degrees_of_freedom}")
print(f"Critical Value: {critical_value}")
# Out:
# Degrees of Freedom: 4
# Critical Value: 9.487729036781154

# %% [markdown]
# **4.Make a Decision:**
# Compare the Chi-Square statistic with the critical value to decide whether to reject the null hypothesis.
#
# H0="a significant association b/w (Smart Thermostats vs. Smart Lights)"
#
# H1="no a significant association b/w (Smart Thermostats vs. Smart Lights) "
#
# Chi2_statistical value=25.192
#
# chi2_critical value=9.487
#
# If,
#
# Chi2_statistical value>chi2_critical value
#
# Then we will consider alternate hypothesis(H1),i.e.,no a significant association b/w  the devices (Smart Thermostats vs. Smart Lights)
#
# Therefore Null hypothesis is rejected(H0).
