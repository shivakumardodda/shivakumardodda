# %% [markdown]
# <a href="https://colab.research.google.com/github/shivakumardodda/shivakumardodda/blob/main/Basic_statistics_salaries.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_csv('Salaries excler.csv')
print(df)
type(df)
#df()#df is dataframe were records are stored
#In python count start from 0
df.head()
df.tail()
df.shape
df.columns
df.isnull()
df.isnull().sum()
df.info()
df.describe()   #it say about the data and mean,std.range and percentage
df['salary'].mean()
df['salary'].mode()
df['salary'].var()
df['salary'].std()
df['salary'].median()
df['salary'].skew()
df.mean(numeric_only=True)
df['salary']>50000
df[df['salary']>50000]
df[df['salary']>50000].count()
df.iloc[:,:]
df.iloc[0:,0:2]
df.loc[:,'salary']
df['rank'].value_counts()
df.max()
df.min()
df.groupby('rank').mean(numeric_only=True)
df['sex'].mode()
df['salary'].mode()
df['sex'].value_counts()
df.groupby('rank').median(numeric_only=True)
df.groupby('rank').mean(numeric_only=True)
df.groupby('rank')[['salary','phd']].mean()
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [78 rows x 6 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 78 entries, 0 to 77
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   rank        78 non-null     object
#  1   discipline  78 non-null     object
# ...

# %%
# Out:
#   File "<ipython-input-64-f08389f8b934>", line 1
#     give me mean of salary
#          ^
# SyntaxError: invalid syntax
