# %% [markdown]
# <a href="https://colab.research.google.com/github/shivakumardodda/shivakumardodda/blob/data-science/PCA_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **DODDA SHIVA KUMAR**

# %%
#importing required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import seaborn as sns

# %% [markdown]
# **Task 1: Exploratory Data Analysis (EDA):**

# %%
#Loading the dataset and performing EDA
df = pd.read_csv('wine.csv')
df
# Out:
#      Type  Alcohol  Malic   Ash  Alcalinity  Magnesium  Phenols  Flavanoids  \
# 0       1    14.23   1.71  2.43        15.6        127     2.80        3.06
# 1       1    13.20   1.78  2.14        11.2        100     2.65        2.76
# 2       1    13.16   2.36  2.67        18.6        101     2.80        3.24
# 3       1    14.37   1.95  2.50        16.8        113     3.85        3.49
# 4       1    13.24   2.59  2.87        21.0        118     2.80        2.69
# ..    ...      ...    ...   ...         ...        ...      ...         ...
# 173     3    13.71   5.65  2.45        20.5         95     1.68        0.61
# 174     3    13.40   3.91  2.48        23.0        102     1.80        0.75
# 175     3    13.27   4.28  2.26        20.0        120     1.59        0.69
# 176     3    13.17   2.59  2.37        20.0        120     1.65        0.68
# 177     3    14.13   4.10  2.74        24.5         96     2.05        0.76
#
# ...

# %%
df.shape
# Out:
# (178, 14)

# %%
#It is used to know the info of the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Type             178 non-null    int64
#  1   Alcohol          178 non-null    float64
#  2   Malic            178 non-null    float64
#  3   Ash              178 non-null    float64
#  4   Alcalinity       178 non-null    float64
#  5   Magnesium        178 non-null    int64
#  6   Phenols          178 non-null    float64
#  7   Flavanoids       178 non-null    float64
#  8   Nonflavanoids    178 non-null    float64
#  9   Proanthocyanins  178 non-null    float64
#  10  Color            178 non-null    float64
#  11  Hue              178 non-null    float64
#  12  Dilution         178 non-null    float64
#  13  Proline          178 non-null    int64
# dtypes: float64(11), int64(3)
# memory usage: 19.6 KB

# %%
#finding the key points in dataset
df.describe()
# Out:
#              Type     Alcohol       Malic         Ash  Alcalinity   Magnesium  \
# count  178.000000  178.000000  178.000000  178.000000  178.000000  178.000000
# mean     1.938202   13.000618    2.336348    2.366517   19.494944   99.741573
# std      0.775035    0.811827    1.117146    0.274344    3.339564   14.282484
# min      1.000000   11.030000    0.740000    1.360000   10.600000   70.000000
# 25%      1.000000   12.362500    1.602500    2.210000   17.200000   88.000000
# 50%      2.000000   13.050000    1.865000    2.360000   19.500000   98.000000
# 75%      3.000000   13.677500    3.082500    2.557500   21.500000  107.000000
# max      3.000000   14.830000    5.800000    3.230000   30.000000  162.000000
#
#           Phenols  Flavanoids  Nonflavanoids  Proanthocyanins       Color  \
# count  178.000000  178.000000     178.000000       178.000000  178.000000
# mean     2.295112    2.029270       0.361854         1.590899    5.058090
# ...

# %%
#Finding the null values
df.isnull().sum()
# Out:
# Type               0
# Alcohol            0
# Malic              0
# Ash                0
# Alcalinity         0
# Magnesium          0
# Phenols            0
# Flavanoids         0
# Nonflavanoids      0
# Proanthocyanins    0
# Color              0
# Hue                0
# Dilution           0
# Proline            0
# dtype: int64

# %%
#2.visulization of the dataset
import matplotlib.pyplot as plt
import seaborn as sns
for col in df.columns:
    plt.figure(figsize=(10,8))
    sns.histplot(df[col])
    plt.title(col)
    plt.show()

# %%
for col in df.columns:
  plt.figure(figsize=(8,6))
  sns.boxplot(y=df[col])
  plt.title(col)
  plt.show()

# %%
#finding the correlation between the features
df.corr()
# Out:
#                      Type   Alcohol     Malic       Ash  Alcalinity  \
# Type             1.000000 -0.328222  0.437776 -0.049643    0.517859
# Alcohol         -0.328222  1.000000  0.094397  0.211545   -0.310235
# Malic            0.437776  0.094397  1.000000  0.164045    0.288500
# Ash             -0.049643  0.211545  0.164045  1.000000    0.443367
# Alcalinity       0.517859 -0.310235  0.288500  0.443367    1.000000
# Magnesium       -0.209179  0.270798 -0.054575  0.286587   -0.083333
# Phenols         -0.719163  0.289101 -0.335167  0.128980   -0.321113
# Flavanoids      -0.847498  0.236815 -0.411007  0.115077   -0.351370
# Nonflavanoids    0.489109 -0.155929  0.292977  0.186230    0.361922
# Proanthocyanins -0.499130  0.136698 -0.220746  0.009652   -0.197327
# Color            0.265668  0.546364  0.248985  0.258887    0.018732
# Hue             -0.617369 -0.071747 -0.561296 -0.074667   -0.273955
# Dilution        -0.788230  0.072343 -0.368710  0.003911   -0.276769
# ...

# %%
import pandas as pd
from scipy import stats
for col in df.columns:
# Assuming your dataset is in a Pandas DataFrame called 'df'

# Method 1: IQR
  Q1 = df[col].quantile(0.25)
  Q3 = df[col].quantile(0.75)
  IQR = Q3 - Q1
  lower_bound = Q1 - 1.5 * IQR
  upper_bound = Q3 + 1.5 * IQR
  df_no_outliers = df[(df[col] >= lower_bound) & (df[col] <= upper_bound)]

# %% [markdown]
# **Task 2: Dimensionality Reduction with PCA:**

# %%
#1.Standardize  the data
scaler = StandardScaler()
df_normal = scaler.fit_transform(df)
df_normal
# Out:
# array([[-1.21394365,  1.51861254, -0.5622498 , ...,  0.36217728,
#          1.84791957,  1.01300893],
#        [-1.21394365,  0.24628963, -0.49941338, ...,  0.40605066,
#          1.1134493 ,  0.96524152],
#        [-1.21394365,  0.19687903,  0.02123125, ...,  0.31830389,
#          0.78858745,  1.39514818],
#        ...,
#        [ 1.37386437,  0.33275817,  1.74474449, ..., -1.61212515,
#         -1.48544548,  0.28057537],
#        [ 1.37386437,  0.20923168,  0.22769377, ..., -1.56825176,
#         -1.40069891,  0.29649784],
#        [ 1.37386437,  1.39508604,  1.58316512, ..., -1.52437837,
#         -1.42894777, -0.59516041]])

# %%
#2.PCA to reduce the dimensionality
pca=PCA(n_components=13)
pca_values=pca.fit_transform(df_normal)
pca_values
# Out:
# array([[-3.52293390e+00,  1.45309844e+00, -1.64795488e-01, ...,
#         -4.20493905e-01,  5.52927766e-01, -3.02978176e-01],
#        [-2.52885806e+00, -3.30019252e-01, -2.02670665e+00, ...,
#         -1.30019629e-01,  3.94971160e-01, -1.46645308e-01],
#        [-2.78502898e+00,  1.03693595e+00,  9.83237703e-01, ...,
#         -2.79074108e-01,  1.89799314e-03,  2.12780166e-02],
#        ...,
#        [ 3.02727243e+00,  2.75604024e+00, -9.40803036e-01, ...,
#          5.02640272e-01,  6.93336340e-01,  1.67035660e-01],
#        [ 2.75522166e+00,  2.29378408e+00, -5.50473677e-01, ...,
#          3.13785741e-01,  3.44119826e-01, -1.09514873e-01],
#        [ 3.49633565e+00,  2.76060799e+00,  1.01315115e+00, ...,
#         -2.38282390e-01, -1.89866131e-01, -1.64090011e-01]])

# %%
#loading or weights
pca.components_
# Out:
# array([[ 0.39366953, -0.13632501,  0.22267638, -0.00225793,  0.22429849,
#         -0.12463016, -0.35926404, -0.39071171,  0.2670012 , -0.2790625 ,
#          0.08931829, -0.27682265, -0.35052618, -0.26951525],
#        [ 0.00569041,  0.48416087,  0.22359095,  0.31585588, -0.01161574,
#          0.30055143,  0.06711983, -0.00131345,  0.0269887 ,  0.04122256,
#          0.52978274, -0.27790735, -0.16277625,  0.36605886],
#        [ 0.00121795, -0.20740081,  0.08879606,  0.62610236,  0.6119896 ,
#          0.13098458,  0.14650775,  0.15096275,  0.16997551,  0.14987959,
#         -0.1372663 ,  0.08532854,  0.16620436, -0.12668685],
#        [ 0.12246373, -0.08191848,  0.46988824, -0.24984122,  0.07199322,
#         -0.16321412,  0.19098521,  0.14461667, -0.32801272,  0.46275771,
#          0.07211248, -0.43466618,  0.15672341, -0.2557949 ],
#        [ 0.15758395, -0.25089415, -0.18860015, -0.0935236 ,  0.0465675 ,
# ...

# %%
#amount of variance in PCA
var=pca.explained_variance_ratio_
var
# Out:
# array([0.39542486, 0.17836259, 0.10329102, 0.06627984, 0.06267875,
#        0.0480556 , 0.03955707, 0.02500244, 0.02103871, 0.01873615,
#        0.01613203, 0.01205691, 0.00925458])

# %%
#cumulative explained variance.
var1=np.cumsum(np.round(var,decimals=4)*100)
var1
# Out:
# array([39.54, 57.38, 67.71, 74.34, 80.61, 85.42, 89.38, 91.88, 93.98,
#        95.85, 97.46, 98.67, 99.6 ])

# %%
#screenplot for the cumulative variance
plt.plot(var1,color="red")

# %%
pca_values[:,0:7]
# Out:
# array([[-3.5229339 ,  1.45309844, -0.16479549, ...,  0.73734536,
#          0.30071618,  0.57387557],
#        [-2.52885806, -0.33001925, -2.02670665, ..., -0.28321373,
#          0.88430941, -0.02971648],
#        [-2.78502898,  1.03693595,  0.9832377 , ..., -0.38756497,
#         -0.46884161,  0.4883054 ],
#        ...,
#        [ 3.02727243,  2.75604024, -0.94080304, ...,  1.12813634,
#         -0.00529036,  0.73302611],
#        [ 2.75522166,  2.29378408, -0.55047368, ...,  1.06708304,
#         -1.01256231,  0.75542325],
#        [ 3.49633565,  2.76060799,  1.01315115, ..., -1.00513627,
#         -0.37722337,  0.01530664]])

# %%
finalDf=pd.concat([pd.DataFrame(pca_values[:,0:7],columns=['PC1','PC2','PC3','PC4','PC5','PC6','PC7']),df[['Type']]],axis=1)
finalDf
# Out:
#           PC1       PC2       PC3       PC4       PC5       PC6       PC7  \
# 0   -3.522934  1.453098 -0.164795 -0.013273  0.737345  0.300716  0.573876
# 1   -2.528858 -0.330019 -2.026707 -0.417144 -0.283214  0.884309 -0.029716
# 2   -2.785029  1.036936  0.983238  0.664232 -0.387565 -0.468842  0.488305
# 3   -3.922588  2.768210 -0.174968  0.565088 -0.324360 -0.262616 -0.398364
# 4   -1.407511  0.867773  2.025829 -0.440906  0.227949  0.593762  0.447876
# ..        ...       ...       ...       ...       ...       ...       ...
# 173  3.627996  2.206617 -0.343668  0.751705 -1.004109  1.143155  0.843455
# 174  2.942729  1.752263  0.207480  0.399381  0.154223  0.062465  0.139947
# 175  3.027272  2.756040 -0.940803  0.607758  1.128136 -0.005290  0.733026
# 176  2.755222  2.293784 -0.550474 -0.391570  1.067083 -1.012562  0.755423
# 177  3.496336  2.760608  1.013151  0.349630 -1.005136 -0.377223  0.015307
#
#      Type
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
# ...

# %% [markdown]
# **Visulization:**
# We cannot visulize the PCA values because the PCA values are more the 3,to get 91% of the we are dealing with 7 PCA values.
#
# So we cannot visuliz the 'PCA' Values on scatter plot.

# %% [markdown]
# **Task 3: Clustering with Original Data:**

# %%
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

# Reload the dataset if necessary
df = pd.read_csv('wine.csv')

# Select features for clustering (excluding 'Type' if it's a target variable)
X = df.drop('Type', axis=1)  # Assuming 'Type' is the target variable

# Standardize the features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
wcss = []  # Within-cluster sum of squares
for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, random_state=42)
    kmeans.fit(X_scaled)
    wcss.append(kmeans.inertia_)

plt.plot(range(1, 11), wcss, marker='o')
plt.title('Elbow Method')
plt.xlabel('Number of Clusters (k)')
plt.ylabel('WCSS')
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# Assuming 'finalDf' contains your PCA results and you want 3 clusters
kmeans = KMeans(n_clusters=3, random_state=42)  # Choose the desired number of clusters
finalDf['Cluster'] = kmeans.fit_predict(finalDf[['PC1', 'PC2', 'PC3', 'PC4', 'PC5', 'PC6', 'PC7']]) # Fit KMeans and assign cluster labels

# Now you can create the scatter plot
plt.figure(figsize=(8, 6))
plt.scatter(finalDf['PC1'], finalDf['PC2'], c=finalDf['Cluster'], cmap='viridis')
plt.title('K-means Clustering Visualization with PCA')
plt.xlabel('Principal Component 1 (PC1)')
plt.ylabel('Principal Component 2 (PC2)')
plt.colorbar(label='Cluster')
plt.show()

# %%
from sklearn.metrics import silhouette_score, davies_bouldin_score

# Assuming 'X_scaled' is your scaled data and 'kmeans.labels_' are the cluster labels
silhouette_avg = silhouette_score(X_scaled, kmeans.labels_)
print("Silhouette Score:", silhouette_avg)

davies_bouldin = davies_bouldin_score(X_scaled, kmeans.labels_)
print("Davies-Bouldin Index:", davies_bouldin)
# Out:
# Silhouette Score: 0.2842603226292969
# Davies-Bouldin Index: 1.385002989414673

# %% [markdown]
# **Task 4: Clustering with PCA Data:**

# %%
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt


df = pd.read_csv('wine.csv')

# %%
# Assuming 'df_normal' is your standardized data
from sklearn.decomposition import PCA
pca = PCA(n_components=7)  # Choose the desired number of components
pca_values = pca.fit_transform(df_normal)


kmeans = KMeans(n_clusters=3, random_state=42)  # Choose the desired number of clusters
clusters = kmeans.fit_predict(pca_values)

# %%
#Visulizing the PCA values on scatter plot:

pca_df = pd.DataFrame(pca_values, columns=['PC1', 'PC2', 'PC3', 'PC4', 'PC5', 'PC6', 'PC7'])
pca_df['Cluster'] = clusters  # Add cluster labels to the PCA-transformed dataset

import matplotlib.pyplot as plt
plt.scatter(pca_values[:, 0], pca_values[:, 1], c=clusters)  # Scatter plot of PC1 vs. PC2
plt.xlabel('Principal Component 1 (PC1)')
plt.ylabel('Principal Component 2 (PC2)')
plt.title('K-Means Clustering on PCA-Transformed Data')
plt.show()

# %%
#Comparing Clustering Results of Original dataset and PCA values:

from sklearn.metrics import silhouette_score, davies_bouldin_score

# Assuming 'X_scaled' is your scaled original data, 'pca_values' is the PCA-transformed data, and 'clusters' are the cluster assignments for both
silhouette_original = silhouette_score(X_scaled, clusters)  # Silhouette score for original data
silhouette_pca = silhouette_score(pca_values, clusters)  # Silhouette score for PCA-transformed data

davies_bouldin_original = davies_bouldin_score(X_scaled, clusters)  # Davies-Bouldin index for original data
davies_bouldin_pca = davies_bouldin_score(pca_values, clusters)  # Davies-Bouldin index for PCA-transformed data

print("Silhouette Score (Original Data):", silhouette_original)
print("Silhouette Score (PCA-transformed Data):", silhouette_pca)
print("Davies-Bouldin Index (Original Data):", davies_bouldin_original)
print("Davies-Bouldin Index (PCA-transformed Data):", davies_bouldin_pca)
# Out:
# Silhouette Score (Original Data): 0.2842603226292969
# Silhouette Score (PCA-transformed Data): 0.35348646523303623
# Davies-Bouldin Index (Original Data): 1.385002989414673
# Davies-Bouldin Index (PCA-transformed Data): 1.1465061614630734

# %% [markdown]
# **Task 5: Comparison and Analysis:**

# %% [markdown]
# **1. Comparison of Clustering Results:**
#
# To compare the clustering results, we'll use two common metrics: the Silhouette Score and the Davies-Bouldin Index. Here's how they apply in this scenario:
#
# Silhouette Score: Measures how similar a data point is to its own cluster compared to other clusters. Higher scores indicate better-defined clusters.
#
# Davies-Bouldin Index: Measures the average similarity between each cluster and its most similar cluster. Lower scores indicate better clustering.

# %% [markdown]
# **2. Similarities and Differences:**
#
# Similarities: Depending on the dataset and the specific PCA transformation, you might find that the clusters formed on the original and PCA-transformed data share some similarities in terms of the data points assigned to each cluster. This means PCA might preserve some of the underlying structure of the data.
#
# Differences: You might also observe differences in the cluster assignments and the overall quality of the clusters. PCA can sometimes improve clustering by reducing noise and highlighting the most important features. However, it can also lead to a loss of information if important features are discarded during dimensionality reduction.

# %% [markdown]
# **3.Impact of Dimensionality Reduction:**
#
# Dimensionality reduction with PCA can have the following effects on clustering performance:
#
# Improved Performance: By reducing noise and focusing on the most relevant features, PCA can sometimes improve the accuracy and efficiency of clustering algorithms. This is especially true when dealing with high-dimensional data where the "curse of dimensionality" can hinder clustering.
#
# Reduced Performance: If PCA removes important features that are crucial for distinguishing between clusters, it can lead to a decrease in clustering performance. It's crucial to carefully select the number of principal components to retain.

# %% [markdown]
# **4. Trade-offs between PCA and Original Data:**
#
# PCA Advantages: Can improve clustering performance, reduce computational cost, and simplify data visualization.
#
# PCA Disadvantages: Can lead to information loss if important features are removed.
#
# Original Data Advantages: Preserves all information in the dataset.
#
# Original Data Disadvantages: Can be computationally expensive and challenging to cluster, especially in high-dimensional spaces.

# %% [markdown]
# **Task 6: Conclusion and Insights**

# %% [markdown]
# 1.Summarize the key findings and insights from the assignment.
#
# Exploratory Data Analysis (EDA): The initial data exploration revealed the dataset's structure, basic statistics, and potential outliers. It's important to perform EDA to gain insights of the dataset to make better decisions for PCA and clustering.
#
# Dimensionality Reduction with PCA: PCA successfully reduced the dimensionality of the dataset while retaining a significant portion of the variance.
#
# Clustering: K-Means clustering was applied to both the original and PCA-transformed data. The elbow method aided in determining the optimal number of clusters.
#
# Evaluation Metrics: Silhouette scores and the Davies-Bouldin Index were employed to evaluate the quality of the clustering results. Comparing the metrics for original and PCA-transformed data helps assess the impact of dimensionality reduction

# %% [markdown]
# 2.Discuss the practical implications of using PCA and clustering in data analysis.
#
# Noise Reduction: By focusing on the principal components that capture the most variance, PCA can effectively reduce noise in the data, leading to more robust and accurate models.
#
# Feature Extraction: PCA can be used to extract the most important features from a dataset, which can be useful for understanding the underlying structure of the data and for building more efficient models.
#
# Visualization: PCA can be used to visualize high-dimensional data in a lower-dimensional space, making it easier to identify patterns and trends.
#
# Clustering:
#
# Customer Segmentation: Clustering can be used to group customers based on their purchasing behavior, demographics, or other characteristics. This information can be used to target marketing campaigns and to develop new products and services.
#
# Anomaly Detection: Clustering can be used to identify outliers or anomalies in data. This can be useful for fraud detection, quality control, and other applications.
#
# Image Segmentation: In image processing, clustering can be used to group pixels into meaningful regions, such as objects or backgrounds. This can be used for object recognition, image editing, and other tasks.

# %% [markdown]
# 3.Provide recommendations for when to use each technique based on the analysis conducted
#
# PCA: Use PCA when you have a high-dimensional dataset and want to reduce the number of features while preserving the most important information. This can improve the performance of clustering algorithms and make it easier to visualize the data.
#
# Clustering: Use clustering when you want to group similar data points together. This can be used for a variety of tasks, such as customer segmentation, anomaly detection, and image segmentation.
#
# PCA and Clustering: Use PCA and clustering together when you have a high-dimensional dataset and want to identify clusters of similar data points. PCA can be used to reduce the dimensionality of the data before applying clustering, which can improve the performance of the clustering algorithm.
